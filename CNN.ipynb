# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# ============================
# 1. Configuração do Early Stopping
# ============================
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=10,  # Aumentando o patience para evitar interrupção precoce
    verbose=1,
    mode='max',
    restore_best_weights=True
)

# ============================
# 2. Configuração dos Dados
# ============================
TRAIN_DIR = "C:/Treinamento IA/Train"

train_datagen = ImageDataGenerator(
    rescale=1.0 / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

train_set = train_datagen.flow_from_directory(
    TRAIN_DIR, target_size=(480, 640), batch_size=32, class_mode='binary', subset='training'
)

val_set = train_datagen.flow_from_directory(
    TRAIN_DIR, target_size=(480, 640), batch_size=32, class_mode='binary', subset='validation'
)

# ============================
# 3. Definição do Modelo
# ============================
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), padding='Same', activation='relu', input_shape=(480, 640, 3),
                           kernel_initializer='he_normal', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(32, (3, 3), padding='Same', activation='relu',
                           kernel_initializer='he_normal', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D((2, 2), strides=(2, 2)),
    
    tf.keras.layers.Conv2D(64, (3, 3), padding='Same', activation='relu',
                           kernel_initializer='he_normal', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(64, (3, 3), padding='Same', activation='relu',
                           kernel_initializer='he_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0005)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D((2, 2), strides=(2, 2)),
    
    tf.keras.layers.Conv2D(128, (3, 3), padding='Same', activation='relu',
                           kernel_initializer='he_normal', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(128, (3, 3), padding='Same', activation='relu',
                           kernel_initializer='he_normal', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D((2, 2), strides=(2, 2)),
    tf.keras.layers.Dropout(0.1),  # Dropout reduzido para 0.1

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu', kernel_initializer='he_normal', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.6),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

print(model.summary())

# ============================
# 4. Compilação do Modelo
# ============================
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),  # Taxa de aprendizado mais baixa
              loss='binary_crossentropy', metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

# ============================
# 5. Configuração do ReduceLROnPlateau
# ============================
reduce_lr = ReduceLROnPlateau(
    monitor='val_accuracy',   # Agora estamos monitorando a precisão de validação
    factor=0.5,               # Fator pelo qual a taxa de aprendizado será reduzida
    patience=5,               # Espera por 5 épocas sem melhoria antes de reduzir a taxa de aprendizado
    verbose=1,                # Exibe as informações durante o treinamento
    mode='max',               # Tentando maximizar a precisão (val_accuracy)
    min_lr=1e-6               # Limite inferior para a taxa de aprendizado
)


# ============================
# 6. Treinamento com EarlyStopping e ReduceLROnPlateau
# ============================
history = model.fit(
    train_set,
    epochs=100,
    validation_data=val_set,
    callbacks=[early_stopping, reduce_lr]
)

# ============================
# 7. Salvamento do Modelo
# ============================
model.save('C:/Treinamento IA/result.keras')

# ============================
# 8. Gráfico de Aprendizado
# ============================
plt.figure(figsize=(12, 6))

# Plot da Acurácia
plt.subplot(1, 3, 1)
plt.plot(history.history['accuracy'], label='Acurácia Treino')
plt.plot(history.history['val_accuracy'], label='Acurácia Validação')
plt.xlabel('Épocas')
plt.ylabel('Acurácia')
plt.legend()
plt.grid(True)
plt.title('Curva de Acurácia')

# Plot da Perda
plt.subplot(1, 3, 2)
plt.plot(history.history['loss'], label='Perda Treino')
plt.plot(history.history['val_loss'], label='Perda Validação')
plt.xlabel('Épocas')
plt.ylabel('Perda')
plt.legend()
plt.grid(True)
plt.title('Curva de Perda')

# Plot da AUC
plt.subplot(1, 3, 3)
plt.plot(history.history['auc'], label='AUC Treino')
plt.plot(history.history['val_auc'], label='AUC Validação')
plt.xlabel('Épocas')
plt.ylabel('AUC')
plt.legend()
plt.grid(True)
plt.title('Curva de AUC')

plt.tight_layout()
plt.show()
# Out:
# Found 481 images belonging to 2 classes.
# Found 119 images belonging to 2 classes.
# c:\Program Files\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 480, 640, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 480, 640, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 480, 640, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 480, 640, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 240, 320, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 240, 320, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 240, 320, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 240, 320, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 240, 320, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 120, 160, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 120, 160, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 120, 160, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 120, 160, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 120, 160, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 60, 80, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 80, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 614400)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │   157,286,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 157,576,737 (601.11 MB)
#  Trainable params: 157,575,329 (601.10 MB)
#  Non-trainable params: 1,408 (5.50 KB)
# None
# c:\Program Files\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 242s 15s/step - accuracy: 0.7093 - auc: 0.7531 - loss: 13.7917 - val_accuracy: 0.5462 - val_auc: 0.5959 - val_loss: 13.5967 - learning_rate: 1.0000e-04
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 227s 14s/step - accuracy: 0.8990 - auc: 0.9439 - loss: 13.0631 - val_accuracy: 0.5378 - val_auc: 0.6750 - val_loss: 13.3707 - learning_rate: 1.0000e-04
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 221s 14s/step - accuracy: 0.8600 - auc: 0.9352 - loss: 12.7320 - val_accuracy: 0.5294 - val_auc: 0.7377 - val_loss: 14.0269 - learning_rate: 1.0000e-04
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 208s 13s/step - accuracy: 0.8816 - auc: 0.9557 - loss: 12.2354 - val_accuracy: 0.4958 - val_auc: 0.5842 - val_loss: 15.8035 - learning_rate: 1.0000e-04
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 213s 13s/step - accuracy: 0.8917 - auc: 0.9564 - loss: 11.8063 - val_accuracy: 0.4958 - val_auc: 0.5167 - val_loss: 17.3032 - learning_rate: 1.0000e-04
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - accuracy: 0.9087 - auc: 0.9704 - loss: 11.3560
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 221s 14s/step - accuracy: 0.9086 - auc: 0.9701 - loss: 11.3514 - val_accuracy: 0.4958 - val_auc: 0.5583 - val_loss: 15.9581 - learning_rate: 1.0000e-04
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 226s 14s/step - accuracy: 0.9379 - auc: 0.9836 - loss: 10.9828 - val_accuracy: 0.5462 - val_auc: 0.6816 - val_loss: 13.8783 - learning_rate: 5.0000e-05
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 228s 14s/step - accuracy: 0.9321 - auc: 0.9740 - loss: 10.8370 - val_accuracy: 0.5714 - val_auc: 0.7028 - val_loss: 13.3187 - learning_rate: 5.0000e-05
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 211s 13s/step - accuracy: 0.9483 - auc: 0.9841 - loss: 10.6169 - val_accuracy: 0.5462 - val_auc: 0.6743 - val_loss: 13.3531 - learning_rate: 5.0000e-05
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 204s 13s/step - accuracy: 0.9372 - auc: 0.9905 - loss: 10.4506 - val_accuracy: 0.5966 - val_auc: 0.7213 - val_loss: 12.2911 - learning_rate: 5.0000e-05
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 206s 13s/step - accuracy: 0.9305 - auc: 0.9824 - loss: 10.2928 - val_accuracy: 0.6134 - val_auc: 0.7353 - val_loss: 11.2830 - learning_rate: 5.0000e-05
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 202s 13s/step - accuracy: 0.9471 - auc: 0.9894 - loss: 10.1020 - val_accuracy: 0.6218 - val_auc: 0.7581 - val_loss: 10.7583 - learning_rate: 5.0000e-05
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 204s 13s/step - accuracy: 0.9461 - auc: 0.9863 - loss: 9.9592 - val_accuracy: 0.6891 - val_auc: 0.7733 - val_loss: 10.3774 - learning_rate: 5.0000e-05
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 205s 13s/step - accuracy: 0.9516 - auc: 0.9885 - loss: 9.7835 - val_accuracy: 0.6807 - val_auc: 0.7785 - val_loss: 10.1937 - learning_rate: 5.0000e-05
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 205s 13s/step - accuracy: 0.9527 - auc: 0.9949 - loss: 9.6202 - val_accuracy: 0.6639 - val_auc: 0.7753 - val_loss: 10.0489 - learning_rate: 5.0000e-05
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 204s 13s/step - accuracy: 0.9495 - auc: 0.9920 - loss: 9.4852 - val_accuracy: 0.6723 - val_auc: 0.7761 - val_loss: 9.8757 - learning_rate: 5.0000e-05
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 203s 13s/step - accuracy: 0.9416 - auc: 0.9852 - loss: 9.3858 - val_accuracy: 0.6891 - val_auc: 0.7944 - val_loss: 9.7283 - learning_rate: 5.0000e-05
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 202s 13s/step - accuracy: 0.9380 - auc: 0.9913 - loss: 9.2203 - val_accuracy: 0.7479 - val_auc: 0.8202 - val_loss: 9.5454 - learning_rate: 5.0000e-05
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 203s 13s/step - accuracy: 0.9712 - auc: 0.9968 - loss: 9.0494 - val_accuracy: 0.7311 - val_auc: 0.8130 - val_loss: 9.4269 - learning_rate: 5.0000e-05
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 202s 13s/step - accuracy: 0.9738 - auc: 0.9868 - loss: 8.9724 - val_accuracy: 0.7899 - val_auc: 0.8682 - val_loss: 9.2041 - learning_rate: 5.0000e-05
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 203s 13s/step - accuracy: 0.9455 - auc: 0.9943 - loss: 8.8331 - val_accuracy: 0.8067 - val_auc: 0.8695 - val_loss: 9.0906 - learning_rate: 5.0000e-05
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 204s 13s/step - accuracy: 0.9674 - auc: 0.9971 - loss: 8.6737 - val_accuracy: 0.8151 - val_auc: 0.8894 - val_loss: 8.9550 - learning_rate: 5.0000e-05
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 205s 13s/step - accuracy: 0.9682 - auc: 0.9870 - loss: 8.6019 - val_accuracy: 0.7563 - val_auc: 0.8487 - val_loss: 8.8905 - learning_rate: 5.0000e-05
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 205s 13s/step - accuracy: 0.9694 - auc: 0.9964 - loss: 8.4511 - val_accuracy: 0.8067 - val_auc: 0.8857 - val_loss: 8.7168 - learning_rate: 5.0000e-05
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 205s 13s/step - accuracy: 0.9786 - auc: 0.9959 - loss: 8.3402 - val_accuracy: 0.8655 - val_auc: 0.9441 - val_loss: 8.5073 - learning_rate: 5.0000e-05
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 205s 13s/step - accuracy: 0.9688 - auc: 0.9954 - loss: 8.2494 - val_accuracy: 0.7647 - val_auc: 0.8538 - val_loss: 8.7157 - learning_rate: 5.0000e-05
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 206s 13s/step - accuracy: 0.9703 - auc: 0.9914 - loss: 8.1618 - val_accuracy: 0.7899 - val_auc: 0.9093 - val_loss: 8.5029 - learning_rate: 5.0000e-05
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 206s 13s/step - accuracy: 0.9685 - auc: 0.9970 - loss: 8.0466 - val_accuracy: 0.7983 - val_auc: 0.8915 - val_loss: 8.3874 - learning_rate: 5.0000e-05
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 204s 13s/step - accuracy: 0.9712 - auc: 0.9979 - loss: 7.9349 - val_accuracy: 0.8487 - val_auc: 0.9316 - val_loss: 8.1453 - learning_rate: 5.0000e-05
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.9419 - auc: 0.9893 - loss: 7.9155
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 206s 13s/step - accuracy: 0.9426 - auc: 0.9893 - loss: 7.9134 - val_accuracy: 0.8403 - val_auc: 0.9282 - val_loss: 8.0995 - learning_rate: 5.0000e-05
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 204s 13s/step - accuracy: 0.9832 - auc: 0.9990 - loss: 7.7628 - val_accuracy: 0.8403 - val_auc: 0.9418 - val_loss: 8.0229 - learning_rate: 2.5000e-05
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 206s 13s/step - accuracy: 0.9830 - auc: 0.9993 - loss: 7.7013 - val_accuracy: 0.8487 - val_auc: 0.9350 - val_loss: 8.0147 - learning_rate: 2.5000e-05
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 204s 13s/step - accuracy: 0.9799 - auc: 0.9983 - loss: 7.6625 - val_accuracy: 0.8571 - val_auc: 0.9422 - val_loss: 7.9506 - learning_rate: 2.5000e-05
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 204s 13s/step - accuracy: 0.9822 - auc: 0.9990 - loss: 7.6038 - val_accuracy: 0.8739 - val_auc: 0.9404 - val_loss: 7.9105 - learning_rate: 2.5000e-05
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 205s 13s/step - accuracy: 0.9881 - auc: 0.9996 - loss: 7.5410 - val_accuracy: 0.8067 - val_auc: 0.9105 - val_loss: 8.1001 - learning_rate: 2.5000e-05
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 204s 13s/step - accuracy: 0.9737 - auc: 0.9975 - loss: 7.5247 - val_accuracy: 0.8319 - val_auc: 0.9442 - val_loss: 7.8905 - learning_rate: 2.5000e-05
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 204s 13s/step - accuracy: 0.9869 - auc: 0.9981 - loss: 7.4622 - val_accuracy: 0.8571 - val_auc: 0.9418 - val_loss: 7.7908 - learning_rate: 2.5000e-05
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 205s 13s/step - accuracy: 0.9855 - auc: 0.9992 - loss: 7.3965 - val_accuracy: 0.8403 - val_auc: 0.9451 - val_loss: 7.7041 - learning_rate: 2.5000e-05
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.9906 - auc: 0.9997 - loss: 7.3472
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 204s 13s/step - accuracy: 0.9907 - auc: 0.9997 - loss: 7.3466 - val_accuracy: 0.8235 - val_auc: 0.9377 - val_loss: 7.7437 - learning_rate: 2.5000e-05
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 204s 13s/step - accuracy: 0.9879 - auc: 0.9993 - loss: 7.3157 - val_accuracy: 0.8571 - val_auc: 0.9499 - val_loss: 7.6193 - learning_rate: 1.2500e-05
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 205s 13s/step - accuracy: 0.9884 - auc: 0.9997 - loss: 7.2786 - val_accuracy: 0.8487 - val_auc: 0.9451 - val_loss: 7.5862 - learning_rate: 1.2500e-05
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 203s 13s/step - accuracy: 0.9941 - auc: 0.9997 - loss: 7.2528 - val_accuracy: 0.8571 - val_auc: 0.9517 - val_loss: 7.5316 - learning_rate: 1.2500e-05
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 204s 13s/step - accuracy: 0.9921 - auc: 0.9997 - loss: 7.2347 - val_accuracy: 0.8487 - val_auc: 0.9439 - val_loss: 7.5720 - learning_rate: 1.2500e-05
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.9915 - auc: 0.9999 - loss: 7.2014
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 204s 13s/step - accuracy: 0.9914 - auc: 0.9999 - loss: 7.2014 - val_accuracy: 0.8571 - val_auc: 0.9432 - val_loss: 7.5353 - learning_rate: 1.2500e-05
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 34.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# ============================
# 1. Carregar os dados de validação
# ============================
VAL_DIR = "C:/Treinamento IA/Validate"

val_datagen = ImageDataGenerator(rescale=1. / 255)
val_set = val_datagen.flow_from_directory(
    VAL_DIR, target_size=(480, 640), batch_size=32, class_mode='binary', shuffle=False
)

# ============================
# 2. Carregar o modelo treinado
# ============================
model = tf.keras.models.load_model('C:/Treinamento IA/result.keras')

# ============================
# 3. Avaliação do modelo
# ============================
results = model.evaluate(val_set)
metrics_names = model.metrics_names

# Exibir todas as métricas retornadas
print("Resultados da avaliação:")
for name, value in zip(metrics_names, results):
    print(f"{name}: {value:.4f}")

# Se quiser apenas loss e accuracy
test_loss, test_accuracy = results[:2]
print(f"Acurácia do modelo carregado: {test_accuracy * 100:.2f}%")

# ============================
# 4. Predições no conjunto de validação
# ============================
y_pred_prob = model.predict(val_set)  # Probabilidades de previsão
y_pred = (y_pred_prob > 0.5).astype(int)  # Converte para 0 ou 1

y_true = val_set.classes  # Valores reais das classes

# ============================
# 5. Matriz de Confusão
# ============================
conf_matrix = confusion_matrix(y_true, y_pred)

def plot_confusion_matrix(cm, class_names):
    plt.figure(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predito')
    plt.ylabel('Real')
    plt.title('Matriz de Confusão')
    plt.show()

plot_confusion_matrix(conf_matrix, class_names=val_set.class_indices.keys())

# ============================
# 6. Relatório de Classificação
# ============================
report = classification_report(y_true, y_pred, target_names=val_set.class_indices.keys())
print("Relatório de Classificação:")
print(report)
# Out:
# Found 151 images belonging to 2 classes.
# c:\Program Files\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8682 - auc: 0.6230 - loss: 7.8937
# Resultados da avaliação:
# loss: 7.8770
# compile_metrics: 0.8675
# Acurácia do modelo carregado: 86.75%
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#     Greening       0.89      0.84      0.87        77
#      Healthy       0.85      0.89      0.87        74
#
#     accuracy                           0.87       151
#    macro avg       0.87      0.87      0.87       151
# weighted avg       0.87      0.87      0.87       151

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# ============================
# 1. Carregar os dados de validação
# ============================
VAL_DIR = "C:/Treinamento IA/Validate"

val_datagen = ImageDataGenerator(rescale=1. / 255)
val_set = val_datagen.flow_from_directory(
    VAL_DIR, target_size=(480, 640), batch_size=32, class_mode='binary', shuffle=False
)

# ============================
# 2. Carregar o modelo treinado
# ============================
model = tf.keras.models.load_model('C:/Treinamento IA/result.keras')

# ============================
# 3. Avaliação do modelo
# ============================
results = model.evaluate(val_set)
metrics_names = model.metrics_names

# Exibir todas as métricas retornadas
print("Resultados da avaliação:")
for name, value in zip(metrics_names, results):
    print(f"{name}: {value:.4f}")

# Se quiser apenas loss e accuracy
test_loss, test_accuracy = results[:2]
print(f"Acurácia do modelo carregado: {test_accuracy * 100:.2f}%")

# ============================
# 4. Predições no conjunto de validação
# ============================
y_pred_prob = model.predict(val_set)  # Probabilidades de previsão
y_pred = (y_pred_prob > 0.5).astype(int)  # Converte para 0 ou 1

y_true = val_set.classes  # Valores reais das classes

# ============================
# 5. Matriz de Confusão
# ============================
conf_matrix = confusion_matrix(y_true, y_pred)

def plot_confusion_matrix(cm, class_names):
    plt.figure(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predito')
    plt.ylabel('Real')
    plt.title('Matriz de Confusão')
    plt.show()

plot_confusion_matrix(conf_matrix, class_names=val_set.class_indices.keys())

# ============================
# 6. Relatório de Classificação
# ============================
report = classification_report(y_true, y_pred, target_names=val_set.class_indices.keys())
print("Relatório de Classificação:")
print(report)
# Out:
# Found 151 images belonging to 2 classes.
# c:\Program Files\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8682 - auc: 0.6230 - loss: 7.8937
# Resultados da avaliação:
# loss: 7.8770
# compile_metrics: 0.8675
# Acurácia do modelo carregado: 86.75%
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#     Greening       0.89      0.84      0.87        77
#      Healthy       0.85      0.89      0.87        74
#
#     accuracy                           0.87       151
#    macro avg       0.87      0.87      0.87       151
# weighted avg       0.87      0.87      0.87       151
